# %% [markdown]
# # Filling,droping,replace

# %% [markdown]
# # First drop unwanted rows and columns

# %% [markdown]
# #1.First import packages

# %%
import pandas as pd

# %% [markdown]
# #2.load dataset

# %%
data= pd.read_csv("https://raw.githubusercontent.com/shaik4182/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/california_cities.csv")

# %%
data
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %% [markdown]
# # Deleting rows and columns by using $drop()$ function
#
# #The $drop()$ function in Pandas be used to delete rows and columns from a DataFrame with the axis set to 0(row) or set to 1(column).
#
# #inplace parameter can be used to alter DataFrames without reassignment.

# %%
data.drop('Unnamed: 0',axis=1)  # here unnamed column is deleted,but it is temperarly
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 1    AgouraHills  34.153333 -118.761667        281.0         922.0
# 2        Alameda  37.756111 -122.274444          NaN          33.0
# 3         Albany  37.886944 -122.297778          NaN          43.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %%
data # see again column unnamed is present in data, because we deleted temperarly
# Out:
#      Unnamed: 0         city       latd       longd  elevation_m  \
# 0             0     Adelanto  34.576111 -117.432778        875.0
# 1             1  AgouraHills  34.153333 -118.761667        281.0
# 2             2      Alameda  37.756111 -122.274444          NaN
# 3             3       Albany  37.886944 -122.297778          NaN
# 4             4     Alhambra  34.081944 -118.135000        150.0
# ..          ...          ...        ...         ...          ...
# 477         477   Yountville  38.403056 -122.362222         30.0
# 478         478        Yreka  41.726667 -122.637500        787.0
# 479         479     YubaCity  39.134722 -121.626111         18.0
# 480         480      Yucaipa  34.030278 -117.048611        798.0
# 481         481  YuccaValley  34.133333 -116.416667       1027.0
#
#      elevation_ft  population_total  area_total_sq_mi  area_land_sq_mi  \
# 0          2871.0             31765            56.027           56.009
# ...

# %%
data.drop('Unnamed: 0',axis=1,inplace=True) #here unnamed data columns is deleted permanently because 'inplaced=True' is used

# %%
data #see here unnamed column is deleted permanently
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 1    AgouraHills  34.153333 -118.761667        281.0         922.0
# 2        Alameda  37.756111 -122.274444          NaN          33.0
# 3         Albany  37.886944 -122.297778          NaN          43.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %% [markdown]
# #deleting row if it unwanted suppose, exmaple taking row 1

# %%
data.drop(1,axis=0) # here row 1 is deleted but  it is temperarly
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 2        Alameda  37.756111 -122.274444          NaN          33.0
# 3         Albany  37.886944 -122.297778          NaN          43.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# 5     AlisoViejo  33.575000 -117.725556        127.0         417.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %%
data #see again row 1  is present in data, because we deleted temperarly
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 1    AgouraHills  34.153333 -118.761667        281.0         922.0
# 2        Alameda  37.756111 -122.274444          NaN          33.0
# 3         Albany  37.886944 -122.297778          NaN          43.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %%
data.drop(1,axis=0,inplace=True) ##here row 1 data is deleted permanently because 'inplaced=True' is used

# %%
data   #see here row 1 is deleted permanently
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 2        Alameda  37.756111 -122.274444          NaN          33.0
# 3         Albany  37.886944 -122.297778          NaN          43.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# 5     AlisoViejo  33.575000 -117.725556        127.0         417.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %% [markdown]
# # multiple rows and columns deleting using $drop()$
#
# suppose examples

# %%
data
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 2        Alameda  37.756111 -122.274444          NaN          33.0
# 3         Albany  37.886944 -122.297778          NaN          43.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# 5     AlisoViejo  33.575000 -117.725556        127.0         417.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %% [markdown]
# deleting multiple columns

# %%
data.drop(['elevation_m','population_total'],axis=1) # here two columns deleted temperarly,and if you want to delete permanently use inplce=True
# Out:
#             city       latd       longd  elevation_ft  area_total_sq_mi  \
# 0       Adelanto  34.576111 -117.432778        2871.0            56.027
# 2        Alameda  37.756111 -122.274444          33.0            22.960
# 3         Albany  37.886944 -122.297778          43.0             5.465
# 4       Alhambra  34.081944 -118.135000         492.0             7.632
# 5     AlisoViejo  33.575000 -117.725556         417.0             7.472
# ..           ...        ...         ...           ...               ...
# 477   Yountville  38.403056 -122.362222          98.0             1.531
# 478        Yreka  41.726667 -122.637500        2582.0            10.053
# 479     YubaCity  39.134722 -121.626111          59.0            14.656
# 480      Yucaipa  34.030278 -117.048611        2618.0            27.893
# 481  YuccaValley  34.133333 -116.416667        3369.0            40.015
#
#      area_land_sq_mi  area_water_sq_mi  area_total_km2  area_land_km2  \
# ...

# %%
del data['area_land_km2'] # del is used to delete permanently for only columns

# %%
data
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 2        Alameda  37.756111 -122.274444          NaN          33.0
# 3         Albany  37.886944 -122.297778          NaN          43.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# 5     AlisoViejo  33.575000 -117.725556        127.0         417.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %% [markdown]
# deleting multiple rows
#
# #here two columns deleted temperarly,and if you want to delete permanently use inplce=True

# %%
data.drop([2,3],axis=0)
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778        875.0        2871.0
# 4       Alhambra  34.081944 -118.135000        150.0         492.0
# 5     AlisoViejo  33.575000 -117.725556        127.0         417.0
# 6        Alturas  41.487222 -120.542500       1332.0        4370.0
# 7     AmadorCity  38.419444 -120.824167        280.0         919.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222         30.0          98.0
# 478        Yreka  41.726667 -122.637500        787.0        2582.0
# 479     YubaCity  39.134722 -121.626111         18.0          59.0
# 480      Yucaipa  34.030278 -117.048611        798.0        2618.0
# 481  YuccaValley  34.133333 -116.416667       1027.0        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %% [markdown]
# # Filling and Replacing the missing values

# %% [markdown]
# 1.First find how many null values are there in dataset
#
# using $isna()$ and $notnull()$
#
# for understanding we use small data

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 
        'age': [42, np.nan, 36, np.nan, 73], 
        'preTestScore': [42, np.nan, 31, 25, np.nan],
        'postTestScore': [25, 94, np.nan, np.nan, 70]}
df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'preTestScore', 'postTestScore'])
df
# Out:
#   first_name last_name   age  preTestScore  postTestScore
# 0      Jason    Miller  42.0          42.0           25.0
# 1      Molly  Jacobson   NaN           NaN           94.0
# 2       Tina       Ali  36.0          31.0            NaN
# 3       Jake    Milner   NaN          25.0            NaN
# 4        Amy     Cooze  73.0           NaN           70.0

# %%
df.isna().sum()
# Out:
# first_name       0
# last_name        0
# age              2
# preTestScore     2
# postTestScore    2
# dtype: int64

# %% [markdown]
# See in above dataset there [2,2,2] null values are there in particular columns names

# %% [markdown]
# # 2.Atfer finding missing values
#
# # Filling missing values using fillna(), replace()

# %%
# filling missing value using fillna(), 
df.fillna(0) # here total data will be fill with 0 in place of NaN
# Out:
#   first_name last_name   age  preTestScore  postTestScore
# 0      Jason    Miller  42.0          42.0           25.0
# 1      Molly  Jacobson   0.0           0.0           94.0
# 2       Tina       Ali  36.0          31.0            0.0
# 3       Jake    Milner   0.0          25.0            0.0
# 4        Amy     Cooze  73.0           0.0           70.0

# %%
#Filling null values with the previous ones

# %%
df.fillna(method='ffill')  # or you can use method='pad'
# Out:
#   first_name last_name   age  preTestScore  postTestScore
# 0      Jason    Miller  42.0          42.0           25.0
# 1      Molly  Jacobson  42.0          42.0           94.0
# 2       Tina       Ali  36.0          31.0           94.0
# 3       Jake    Milner  36.0          25.0           94.0
# 4        Amy     Cooze  73.0          25.0           70.0

# %%
df
# Out:
#   first_name last_name   age  preTestScore  postTestScore
# 0      Jason    Miller  42.0          42.0           25.0
# 1      Molly  Jacobson   NaN           NaN           94.0
# 2       Tina       Ali  36.0          31.0            NaN
# 3       Jake    Milner   NaN          25.0            NaN
# 4        Amy     Cooze  73.0           NaN           70.0

# %% [markdown]
# #Filling null value with the next ones means backward

# %%
df.fillna(method='bfill')
# Out:
#   first_name last_name   age  preTestScore  postTestScore
# 0      Jason    Miller  42.0          42.0           25.0
# 1      Molly  Jacobson  36.0          31.0           94.0
# 2       Tina       Ali  36.0          31.0           70.0
# 3       Jake    Milner  73.0          25.0           70.0
# 4        Amy     Cooze  73.0           NaN           70.0

# %% [markdown]
# # $replace()$ function is used to replace values given in to_replace with value

# %%
df.replace(np.nan,0) # here total nan values fill with 0
# Out:
#   first_name last_name   age  preTestScore  postTestScore
# 0      Jason    Miller  42.0          42.0           25.0
# 1      Molly  Jacobson   0.0           0.0           94.0
# 2       Tina       Ali  36.0          31.0            0.0
# 3       Jake    Milner   0.0          25.0            0.0
# 4        Amy     Cooze  73.0           0.0           70.0

# %%
df['age'].replace(np.nan,100) # replace value in particular column
# Out:
# 0     42.0
# 1    100.0
# 2     36.0
# 3    100.0
# 4     73.0
# Name: age, dtype: float64

# %%
np.mean(df)
# Out:
# age              50.333333
# preTestScore     32.666667
# postTestScore    63.000000
# dtype: float64

# %% [markdown]
# we can replace with mean,median,sum... values also

# %%
# here total nan values fill with mean values
df.replace(np.nan,np.mean(df))
# Out:
#   first_name last_name        age  preTestScore  postTestScore
# 0      Jason    Miller  42.000000     42.000000           25.0
# 1      Molly  Jacobson  50.333333     32.666667           94.0
# 2       Tina       Ali  36.000000     31.000000           63.0
# 3       Jake    Milner  50.333333     25.000000           63.0
# 4        Amy     Cooze  73.000000     32.666667           70.0

# %%
Df = pd.DataFrame([[1,np.nan,2,None],
                  [2,3,5,np.nan],
                  [np.nan,4,9,None],
                  [10,20,30,40]],columns=['A','B','C','D'])
Df
# Out:
#       A     B   C     D
# 0   1.0   NaN   2   NaN
# 1   2.0   3.0   5   NaN
# 2   NaN   4.0   9   NaN
# 3  10.0  20.0  30  40.0

# %%
Df.dropna() # by default you get row which does not have null values
# Out:
#       A     B   C     D
# 3  10.0  20.0  30  40.0

# %%
Df.dropna(axis=1) #by default you get column which does not have null values
# Out:
#     C
# 0   2
# 1   5
# 2   9
# 3  30

# %%
Df.dropna(axis='columns',how='all') #we will get all values including null values
# Out:
#       A     B   C     D
# 0   1.0   NaN   2   NaN
# 1   2.0   3.0   5   NaN
# 2   NaN   4.0   9   NaN
# 3  10.0  20.0  30  40.0

# %%
Df.dropna(axis='columns',how='any') # we will get only non null values
# Out:
#       A     B   C     D
# 3  10.0  20.0  30  40.0
