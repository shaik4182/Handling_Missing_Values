# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import pandas_profiling

# %%
california_cities=pd.read_csv("https://raw.githubusercontent.com/shaik4182/Data-Sets-For-Machine-Learnig-and-Data-Science/master/DataSets/california_cities.csv")

# %%
california_cities
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778   875.000000        2871.0
# 1    AgouraHills  34.153333 -118.761667   281.000000         922.0
# 2        Alameda  37.756111 -122.274444   180.416705          33.0
# 3         Albany  37.886944 -122.297778   180.416705          43.0
# 4       Alhambra  34.081944 -118.135000   150.000000         492.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222    30.000000          98.0
# 478        Yreka  41.726667 -122.637500   787.000000        2582.0
# 479     YubaCity  39.134722 -121.626111    18.000000          59.0
# 480      Yucaipa  34.030278 -117.048611   798.000000        2618.0
# 481  YuccaValley  34.133333 -116.416667  1027.000000        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %%
california_cities.isna() # to find NaN values
# Out:
#       city   latd  longd  elevation_m  elevation_ft  population_total  \
# 0    False  False  False        False         False             False
# 1    False  False  False        False         False             False
# 2    False  False  False        False         False             False
# 3    False  False  False        False         False             False
# 4    False  False  False        False         False             False
# ..     ...    ...    ...          ...           ...               ...
# 477  False  False  False        False         False             False
# 478  False  False  False        False         False             False
# 479  False  False  False        False         False             False
# 480  False  False  False        False         False             False
# 481  False  False  False        False         False             False
#
#      area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  area_total_km2  \
# ...

# %%
california_cities.isna().sum() # to get how many nan values are present in data
# Out:
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         0
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
a =california_cities['elevation_m'].mean()  # to find the mean value in a particular column
a
# Out:
# 180.41670506912445

# %%
california_cities.fillna({'elevation_m':a},inplace=True) # to fill nan values with mean

# %%
california_cities['elevation_m'].isna().sum()
# Out:
# 0

# %%
california_cities['elevation_m']
# Out:
# 0       875.000000
# 1       281.000000
# 2       180.416705
# 3       180.416705
# 4       150.000000
#           ...
# 477      30.000000
# 478     787.000000
# 479      18.000000
# 480     798.000000
# 481    1027.000000
# Name: elevation_m, Length: 482, dtype: float64

# %%
california_cities.to_csv("california_cities.csv") # to save file in csv

# %%
b = california_cities['elevation_ft'].mean()
b
# Out:
# 567.1687234042553

# %%
california_cities['elevation_ft'].fillna(method='bfill',inplace=True) # to fill nan values using method back fill
california_cities
# Out:
#             city       latd       longd  elevation_m  elevation_ft  \
# 0       Adelanto  34.576111 -117.432778   875.000000        2871.0
# 1    AgouraHills  34.153333 -118.761667   281.000000         922.0
# 2        Alameda  37.756111 -122.274444   180.416705          33.0
# 3         Albany  37.886944 -122.297778   180.416705          43.0
# 4       Alhambra  34.081944 -118.135000   150.000000         492.0
# ..           ...        ...         ...          ...           ...
# 477   Yountville  38.403056 -122.362222    30.000000          98.0
# 478        Yreka  41.726667 -122.637500   787.000000        2582.0
# 479     YubaCity  39.134722 -121.626111    18.000000          59.0
# 480      Yucaipa  34.030278 -117.048611   798.000000        2618.0
# 481  YuccaValley  34.133333 -116.416667  1027.000000        3369.0
#
#      population_total  area_total_sq_mi  area_land_sq_mi  area_water_sq_mi  \
# 0               31765            56.027           56.009             0.018
# ...

# %%
california_cities.to_csv('california_cities.csv')

# %%
california_cities.isna().sum()
# Out:
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         0
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
california_cities['area_total_sq_mi'].fillna(method='ffill',inplace=True) # to fill nan values using method forward fill

# %%
california_cities.isna().sum()
# Out:
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         0
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
california_cities['area_water_sq_mi'].fillna(0,inplace=True) # to fill nan values without using method

# %%
california_cities.isna().sum()
# Out:
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         0
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
california_cities.isna().sum()
# Out:
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         0
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
california_cities['area_total_km2'].fillna(method='ffill',inplace=True)
california_cities['area_land_km2'].fillna(method='ffill',inplace=True)
california_cities['area_water_km2'].fillna(method='ffill',inplace=True)
california_cities['area_water_percent'].fillna(method='ffill',inplace=True)

# %%
california_cities.isna().sum()
# Out:
# city                  0
# latd                  0
# longd                 0
# elevation_m           0
# elevation_ft          0
# population_total      0
# area_total_sq_mi      0
# area_land_sq_mi       0
# area_water_sq_mi      0
# area_total_km2        0
# area_land_km2         0
# area_water_km2        0
# area_water_percent    0
# dtype: int64

# %%
california_cities.to_csv("california_cities.csv")
